# %%
# %run ./setup

# %%
df_vendas = pd.read_csv('d../data/vendas.csv')

# %%
vis_spec = r"""{"config":[{"config":{"defaultAggregated":true,"geoms":["auto"],"coordSystem":"generic","limit":-1,"timezoneDisplayOffset":0},"encodings":{"dimensions":[{"fid":"pedido_id","name":"pedido_id","basename":"pedido_id","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"data_hora","name":"data_hora","basename":"data_hora","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"data","name":"data","basename":"data","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"mes","name":"mes","basename":"mes","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"dia_semana","name":"dia_semana","basename":"dia_semana","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"canal","name":"canal","basename":"canal","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"cidade","name":"cidade","basename":"cidade","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"vendedor","name":"vendedor","basename":"vendedor","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"produto","name":"produto","basename":"produto","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"categoria","name":"categoria","basename":"categoria","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"quantidade","name":"quantidade","basename":"quantidade","semanticType":"quantitative","analyticType":"dimension","offset":0},{"fid":"pagamento","name":"pagamento","basename":"pagamento","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"gw_mea_key_fid","name":"Measure names","analyticType":"dimension","semanticType":"nominal"}],"measures":[{"fid":"preco_unitario","name":"preco_unitario","basename":"preco_unitario","analyticType":"measure","semanticType":"quantitative","aggName":"sum","offset":0},{"fid":"desconto_pct","name":"desconto_pct","basename":"desconto_pct","analyticType":"measure","semanticType":"quantitative","aggName":"sum","offset":0},{"fid":"frete","name":"frete","basename":"frete","analyticType":"measure","semanticType":"quantitative","aggName":"sum","offset":0},{"fid":"valor_bruto","name":"valor_bruto","basename":"valor_bruto","analyticType":"measure","semanticType":"quantitative","aggName":"sum","offset":0},{"fid":"valor_desconto","name":"valor_desconto","basename":"valor_desconto","analyticType":"measure","semanticType":"quantitative","aggName":"sum","offset":0},{"fid":"valor_total","name":"valor_total","basename":"valor_total","analyticType":"measure","semanticType":"quantitative","aggName":"sum","offset":0},{"fid":"gw_count_fid","name":"Row count","analyticType":"measure","semanticType":"quantitative","aggName":"sum","computed":true,"expression":{"op":"one","params":[],"as":"gw_count_fid"}},{"fid":"gw_mea_val_fid","name":"Measure values","analyticType":"measure","semanticType":"quantitative","aggName":"sum"}],"rows":[{"fid":"gw_count_fid","name":"Row count","analyticType":"measure","semanticType":"quantitative","aggName":"sum","computed":true,"expression":{"op":"one","params":[],"as":"gw_count_fid"}}],"columns":[{"fid":"mes","name":"mes","basename":"mes","semanticType":"nominal","analyticType":"dimension","offset":0}],"color":[],"opacity":[],"size":[],"shape":[],"radius":[],"theta":[],"longitude":[],"latitude":[],"geoId":[],"details":[],"filters":[{"fid":"vendedor","name":"vendedor","basename":"vendedor","semanticType":"nominal","analyticType":"dimension","offset":0,"rule":{"type":"not in","value":[null]}}],"text":[]},"layout":{"showActions":false,"showTableSummary":false,"stack":"stack","interactiveScale":false,"zeroScale":true,"size":{"mode":"full","width":320,"height":200},"format":{},"geoKey":"name","resolve":{"x":false,"y":false,"color":false,"opacity":false,"shape":false,"size":false}},"visId":"gw_sLJ4","name":"Chart 1"}],"chart_map":{},"workflow_list":[{"workflow":[{"type":"filter","filters":[{"fid":"vendedor","rule":{"type":"not in","value":[null]}}]},{"type":"transform","transform":[{"key":"gw_count_fid","expression":{"op":"one","params":[],"as":"gw_count_fid"}}]},{"type":"view","query":[{"op":"aggregate","groupBy":["mes"],"measures":[{"field":"gw_count_fid","agg":"sum","asFieldKey":"gw_count_fid_sum"}]}]}]}],"version":"0.4.9.15"}"""
pyg.walk(df_vendas, spec=vis_spec)
