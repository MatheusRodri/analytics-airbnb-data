# %%
# %pip install -r ../requirements.txt
dbutils.library.restartPython()

print("All libraries installed and Python restarted.")

# %%
import pandas as pd
import pygwalker as pyg

print("Libraries imported successfully.")
